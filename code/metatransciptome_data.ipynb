# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import operator
import plotly.express as px

# %%
data = pd.read_csv("Fw_ lake mendota data/coverm_431_MAGS_metatransciptome_count.tsv", sep='\t')
data=data.T
data.columns = data.iloc[0]

# drop the first row
data= data.iloc[1:]
data
# Out:
# Genome                                 Ga0485165_metabat1.097_sub  \
# ME_2020_07_24_15m_B.fastq Read Count                          929
# ME_2020_07_24_23_5M_B.fastq Read Count                      12747
# ME_2020_07_24_5m_C.fastq Read Count                            24
# ME_2020_08_05_10M_B.fastq Read Count                           40
# ME_2020_08_05_15M_B.fastq Read Count                          416
# ME_2020_08_05_23_5M_B.fastq Read Count                      14680
# ME_2020_08_25_10M_B.fastq Read Count                            5
# ME_2020_08_25_15M_B.fastq Read Count                         2190
# ME_2020_08_25_23_5M_B.fastq Read Count                      14941
# ME_2020_09_11_15M_B.fastq Read Count                         4319
# ME_2020_09_11_23_5M_B.fastq Read Count                       7175
# ME_2020_10_08_15M_B.fastq Read Count                           20
# ME_2020_10_08_23_5M_B.fastq Read Count                       3323
# ME_2020_10_19_15M_B.fastq Read Count                            7
# ME_2020_10_19_23_5M_B.fastq Read Count                        173
# ME_2020_10_19_5M_B.fastq Read Count                            10
#
# Genome                                 Ga0485163_maxbin.015_sub  \
# ME_2020_07_24_15m_B.fastq Read Count                        136
# ME_2020_07_24_23_5M_B.fastq Read Count                      264
# ME_2020_07_24_5m_C.fastq Read Count                         538
# ME_2020_08_05_10M_B.fastq Read Count                        589
# ME_2020_08_05_15M_B.fastq Read Count                        199
# ME_2020_08_05_23_5M_B.fastq Read Count                      224
# ME_2020_08_25_10M_B.fastq Read Count                        961
# ME_2020_08_25_15M_B.fastq Read Count                        539
# ME_2020_08_25_23_5M_B.fastq Read Count                      252
# ME_2020_09_11_15M_B.fastq Read Count                        350
# ME_2020_09_11_23_5M_B.fastq Read Count                       98
# ME_2020_10_08_15M_B.fastq Read Count                        646
# ME_2020_10_08_23_5M_B.fastq Read Count                       95
# ME_2020_10_19_15M_B.fastq Read Count                        443
# ME_2020_10_19_23_5M_B.fastq Read Count                      327
# ME_2020_10_19_5M_B.fastq Read Count                         379
#
# Genome                                 Ga0485161_metabat1.109_sub  \
# ME_2020_07_24_15m_B.fastq Read Count                        21252
# ME_2020_07_24_23_5M_B.fastq Read Count                       7253
# ME_2020_07_24_5m_C.fastq Read Count                          7615
# ME_2020_08_05_10M_B.fastq Read Count                         3019
# ME_2020_08_05_15M_B.fastq Read Count                        15025
# ME_2020_08_05_23_5M_B.fastq Read Count                       3782
# ME_2020_08_25_10M_B.fastq Read Count                         1686
# ME_2020_08_25_15M_B.fastq Read Count                         9722
# ME_2020_08_25_23_5M_B.fastq Read Count                       2107
# ME_2020_09_11_15M_B.fastq Read Count                         5168
# ME_2020_09_11_23_5M_B.fastq Read Count                       1019
# ME_2020_10_08_15M_B.fastq Read Count                         2913
# ME_2020_10_08_23_5M_B.fastq Read Count                       1246
# ME_2020_10_19_15M_B.fastq Read Count                         4111
# ME_2020_08_05_15M_B.fastq Read Count                       2424
# ME_2020_08_05_23_5M_B.fastq Read Count                      894
# ME_2020_08_25_10M_B.fastq Read Count                       1093
# ME_2020_08_25_15M_B.fastq Read Count                        751
# ME_2020_08_25_23_5M_B.fastq Read Count                      570
# ME_2020_09_11_15M_B.fastq Read Count                        308
# ME_2020_09_11_23_5M_B.fastq Read Count                      202
# ME_2020_10_08_15M_B.fastq Read Count                        478
# ME_2020_10_08_23_5M_B.fastq Read Count                      172
# ME_2020_10_19_15M_B.fastq Read Count                        106
# ME_2020_10_19_23_5M_B.fastq Read Count                       81
# ME_2020_10_19_5M_B.fastq Read Count                          87
#
# Genome                                 Ga0485159_metabat2_ours.140_sub
# ME_2020_07_24_15m_B.fastq Read Count                               398
# ME_2020_07_24_23_5M_B.fastq Read Count                             108
# ME_2020_07_24_5m_C.fastq Read Count                               6459
# ME_2020_08_05_10M_B.fastq Read Count                              1112
# ME_2020_08_05_15M_B.fastq Read Count                               286
# ME_2020_08_05_23_5M_B.fastq Read Count                             287
# ME_2020_08_25_10M_B.fastq Read Count                               392
# ME_2020_08_25_15M_B.fastq Read Count                               311
# ME_2020_08_25_23_5M_B.fastq Read Count                             126
# ME_2020_09_11_15M_B.fastq Read Count                               217
# ME_2020_09_11_23_5M_B.fastq Read Count                             127
# ME_2020_10_08_15M_B.fastq Read Count                                90
# ME_2020_10_08_23_5M_B.fastq Read Count                             126
# ME_2020_10_19_15M_B.fastq Read Count                               139
# ME_2020_10_19_23_5M_B.fastq Read Count                              73
# ME_2020_10_19_5M_B.fastq Read Count                                 92
#
# [16 rows x 431 columns]

# %%
data.to_csv("metatransciptome_count.csv")

# %%
#update the daa with all the environmental features

# %%
# Load the taxonomy file again (repeating due to re-upload)
taxonomy_file_path = 'Fw_ lake mendota data/MAG_taxonomy.tsv'
taxonomy_df = pd.read_csv(taxonomy_file_path, sep='\t')

# Load the T-count file
t_count_file_path = 'metatransciptome_count.csv'
t_count_df = pd.read_csv(t_count_file_path)

# Display the first few rows of each dataframe to ensure correct loading
(taxonomy_df.head(), t_count_df.head())
# Out:
# (                       Genome       Domain            Phylum            Class  \
#  0  Ga0485163_metabat1.110_sub  d__Bacteria  p__Chloroflexota  c__Anaerolineae
#  1        Ga0485159_maxbin.015  d__Bacteria   p__Bacteroidota   c__Bacteroidia
#  2  Ga0485168_metabat1.080_sub  d__Bacteria   p__Bacteroidota   c__Bacteroidia
#  3    Ga0485168_maxbin.166_sub  d__Bacteria   p__Bacteroidota   c__Bacteroidia
#  4    Ga0485170_maxbin.116_sub  d__Bacteria   p__Bacteroidota   c__Bacteroidia
#
#                   Order              Family      Genus                Species
#  0     o__Caldilineales   f__Caldilineaceae    g__CFX5                    s__
#  1   o__Chitinophagales         f__UBA10324  g__BJGO01  s__BJGO01 sp014190535
#  2           o__AKYH767  f__2-12-FULL-35-15        g__                    s__
#  3  o__Flavobacteriales  f__Schleiferiaceae  g__TMED14                    s__
#  4  o__Flavobacteriales  f__Schleiferiaceae  g__TMED14                    s__  ,
#                                 Unnamed: 0  Ga0485165_metabat1.097_sub  \
#  0    ME_2020_07_24_15m_B.fastq Read Count                         929
#  1  ME_2020_07_24_23_5M_B.fastq Read Count                       12747
#  2     ME_2020_07_24_5m_C.fastq Read Count                          24
#  3    ME_2020_08_05_10M_B.fastq Read Count                          40
#  4    ME_2020_08_05_15M_B.fastq Read Count                         416
#
#     Ga0485163_maxbin.015_sub  Ga0485161_metabat1.109_sub  \
#  0                       136                       21252
#  1                       264                        7253
#  2                       538                        7615
#  3                       589                        3019
#  4                       199                       15025
#
#     Ga0485163_metabat1.131  Ga0485165_metabat2_ours.031  \
#  0                   78567                       203159
#  1                   11930                        83501
#  2                     201                           50
#  3                  305572                         3168
#  4                   60601                       381617
#
#     Ga0485163_metabat1.023_sub  Ga0485171_metabat2_ours.194  \
#  0                        1456                          296
#  1                         585                           49
#  2                        8188                          139
#  3                        5636                          155
#  4                        1039                          127
#
#     Ga0485163_maxbin.004_sub  Ga0485162_metabat2_ours.116  ...  depth  \
#  0                       285                         1456  ...   15.0
#  1                        80                         4612  ...   23.5
#  2                       401                           16  ...    5.0
#  3                      1471                           49  ...   10.0
#  4                       289                         1084  ...   15.0
#
#     wtemp_in_celsius  DO_sat_perc  DO_mg_L  specific_conductivity    PH  \
#  0             12.03         -1.7    -0.18                 581.66  7.37
#  1             10.31         -1.5    -0.16                 600.14  7.17
#  2             25.05        109.1     9.00                 492.70  8.62
#  3             18.50         -0.7    -0.07                 570.32  7.47
#  4             11.76         -1.1    -0.12                 582.32  7.41
#
#     chlorophyll_RFU  phycocyanin_RFU  Dissolved_organic_matter_RFU  \
#  0             0.14             0.53                         12.18
#  1             0.35             0.88                         12.65
#  2             0.56             1.70                          9.70
#  3             0.33             0.87                         11.63
#  4             0.22             0.67                         12.18
#
#     Turbidity_RFU
#  0           0.59
#  1           1.71
#  2           4.99
#  3           0.86
#  4           0.72
#
#  [5 rows x 442 columns])

# %% [markdown]
# # top 10

# %%
genome_to_phylum_map = dict(zip(taxonomy_df['Genome'], taxonomy_df['Phylum']))

# List of genome names to map to Phylum
genomes_list = [
    'Ga0485157_metabat1.059',
    'Ga0485167_maxbin.109',
    'Ga0485162_maxbin.089',
    'Ga0485161_maxbin.110',
    'Ga0485161_maxbin.075',
    'Ga0485157_metabat1.036',
    'Ga0485165_metabat2_ours.012_sub',
    'Ga0485169_maxbin.201_sub',
    'Ga0485172_maxbin.081_sub',
    'Ga0485168_maxbin.153'
    
]
# Resetting the DataFrame to its original state before reapplying changes with the new requirement
t_count_df = pd.read_csv(t_count_file_path)

# Applying the updated mapping with sequence numbers
for i, genome in enumerate(genomes_list, start=1):
    phylum = genome_to_phylum_map.get(genome)
    if phylum and genome in t_count_df.columns:
        new_column_name = f"{phylum}_{i}"  # Append underscore and sequence number
        t_count_df = t_count_df.rename(columns={genome: new_column_name})

# Display the first few rows of the modified DataFrame to verify changes
t_count_df.head()
# Out:
#                                Unnamed: 0  Ga0485165_metabat1.097_sub  \
# 0    ME_2020_07_24_15m_B.fastq Read Count                         929
# 1  ME_2020_07_24_23_5M_B.fastq Read Count                       12747
# 2     ME_2020_07_24_5m_C.fastq Read Count                          24
# 3    ME_2020_08_05_10M_B.fastq Read Count                          40
# 4    ME_2020_08_05_15M_B.fastq Read Count                         416
#
#    Ga0485163_maxbin.015_sub  Ga0485161_metabat1.109_sub  \
# 0                       136                       21252
# 1                       264                        7253
# 2                       538                        7615
# 3                       589                        3019
# 4                       199                       15025
#
#    Ga0485163_metabat1.131  Ga0485165_metabat2_ours.031  \
# 0                   78567                       203159
# 1                   11930                        83501
# 2                     201                           50
# 3                  305572                         3168
# 4                   60601                       381617
#
#    Ga0485163_metabat1.023_sub  Ga0485171_metabat2_ours.194  \
# 0                        1456                          296
# 1                         585                           49
# 2                        8188                          139
# 3                        5636                          155
# 4                        1039                          127
#
#    Ga0485163_maxbin.004_sub  Ga0485162_metabat2_ours.116  ...  depth  \
# 0                       285                         1456  ...   15.0
# 1                        80                         4612  ...   23.5
# 2                       401                           16  ...    5.0
# 3                      1471                           49  ...   10.0
# 4                       289                         1084  ...   15.0
#
#    wtemp_in_celsius  DO_sat_perc  DO_mg_L  specific_conductivity    PH  \
# 0             12.03         -1.7    -0.18                 581.66  7.37
# 1             10.31         -1.5    -0.16                 600.14  7.17
# 2             25.05        109.1     9.00                 492.70  8.62
# 3             18.50         -0.7    -0.07                 570.32  7.47
# 4             11.76         -1.1    -0.12                 582.32  7.41
#
#    chlorophyll_RFU  phycocyanin_RFU  Dissolved_organic_matter_RFU  \
# 0             0.14             0.53                         12.18
# 1             0.35             0.88                         12.65
# 2             0.56             1.70                          9.70
# 3             0.33             0.87                         11.63
# 4             0.22             0.67                         12.18
#
#    Turbidity_RFU
# 0           0.59
# 1           1.71
# 2           4.99
# 3           0.86
# 4           0.72
#
# [5 rows x 442 columns]

# %%
import os
directory = "metatransciptome"

# Check if the directory exists
if not os.path.exists(directory):
    os.makedirs(directory)  # Create the directory if it does not exist

# Path for saving the CSV file
file_path = os.path.join(directory, 'tax_10.csv')

# Save the DataFrame to CSV
t_count_df.to_csv(file_path, index=True)

# %% [markdown]
# # Top 15

# %%
# List of genome names to map to Phylum
genomes_list = [
    'Ga0485157_metabat1.059',
    'Ga0485167_maxbin.109',
    'Ga0485162_maxbin.089',
    'Ga0485161_maxbin.110',
    'Ga0485161_maxbin.075',
    'Ga0485157_metabat1.036',
    'Ga0485165_metabat2_ours.012_sub',
    'Ga0485169_maxbin.201_sub',
    'Ga0485172_maxbin.081_sub',
    'Ga0485168_maxbin.153',
    'Ga0485172_metabat2_ours.083',
    'Ga0485162_maxbin.023',
    'Ga0485160_maxbin.092',
    'Ga0485158_metabat2_jgi.024',
    'Ga0485162_metabat1.001'
]


# Applying the updated mapping with sequence numbers
for i, genome in enumerate(genomes_list, start=1):
    phylum = genome_to_phylum_map.get(genome)
    if phylum and genome in t_count_df.columns:
        new_column_name = f"{phylum}_{i}"  # Append underscore and sequence number
        t_count_df = t_count_df.rename(columns={genome: new_column_name})

# Display the first few rows of the modified DataFrame to verify changes
t_count_df.head()
# Out:
#                                Unnamed: 0  Ga0485165_metabat1.097_sub  \
# 0    ME_2020_07_24_15m_B.fastq Read Count                         929
# 1  ME_2020_07_24_23_5M_B.fastq Read Count                       12747
# 2     ME_2020_07_24_5m_C.fastq Read Count                          24
# 3    ME_2020_08_05_10M_B.fastq Read Count                          40
# 4    ME_2020_08_05_15M_B.fastq Read Count                         416
#
#    Ga0485163_maxbin.015_sub  Ga0485161_metabat1.109_sub  \
# 0                       136                       21252
# 1                       264                        7253
# 2                       538                        7615
# 3                       589                        3019
# 4                       199                       15025
#
#    Ga0485163_metabat1.131  Ga0485165_metabat2_ours.031  \
# 0                   78567                       203159
# 1                   11930                        83501
# 2                     201                           50
# 3                  305572                         3168
# 4                   60601                       381617
#
#    Ga0485163_metabat1.023_sub  Ga0485171_metabat2_ours.194  \
# 0                        1456                          296
# 1                         585                           49
# 2                        8188                          139
# 3                        5636                          155
# 4                        1039                          127
#
#    Ga0485163_maxbin.004_sub  Ga0485162_metabat2_ours.116  ...  depth  \
# 0                       285                         1456  ...   15.0
# 1                        80                         4612  ...   23.5
# 2                       401                           16  ...    5.0
# 3                      1471                           49  ...   10.0
# 4                       289                         1084  ...   15.0
#
#    wtemp_in_celsius  DO_sat_perc  DO_mg_L  specific_conductivity    PH  \
# 0             12.03         -1.7    -0.18                 581.66  7.37
# 1             10.31         -1.5    -0.16                 600.14  7.17
# 2             25.05        109.1     9.00                 492.70  8.62
# 3             18.50         -0.7    -0.07                 570.32  7.47
# 4             11.76         -1.1    -0.12                 582.32  7.41
#
#    chlorophyll_RFU  phycocyanin_RFU  Dissolved_organic_matter_RFU  \
# 0             0.14             0.53                         12.18
# 1             0.35             0.88                         12.65
# 2             0.56             1.70                          9.70
# 3             0.33             0.87                         11.63
# 4             0.22             0.67                         12.18
#
#    Turbidity_RFU
# 0           0.59
# 1           1.71
# 2           4.99
# 3           0.86
# 4           0.72
#
# [5 rows x 442 columns]

# %%
t_count_df.to_csv('metatransciptome/tax_15.csv', index=True)

# %% [markdown]
# # betweenness

# %%
# List of genome names to map to Phylum
genomes_list = [
    "Ga0485158_maxbin.120_sub",
"Ga0485170_maxbin.090",
"Ga0485159_metabat1.040",
"Ga0485167_metabat2_ours.163",
"Ga0485166_metabat2_ours.038",
"Ga0485162_metabat2_ours.116",
"Ga0485162_metabat2_ours.050",
"Ga0485163_metabat1.181",
"Ga0485158_metabat2_ours.098",
"Ga0485169_metabat2_ours.035",
"Ga0485159_metabat2_ours.130_sub",
"Ga0485163_metabat1.115_sub",
"Ga0485159_maxbin.025",
"Ga0485161_metabat1.096",
"Ga0485167_metabat1.127_sub"

]
# Load the taxonomy file again (repeating due to re-upload)
taxonomy_file_path = 'Fw_ lake mendota data/MAG_taxonomy.tsv'
taxonomy_df = pd.read_csv(taxonomy_file_path, sep='\t')

# Load the T-count file
t_count_file_path = 'metatransciptome_count.csv'
t_count_df = pd.read_csv(t_count_file_path)
genome_to_phylum_map = dict(zip(taxonomy_df['Genome'], taxonomy_df['Phylum']))
t_count_df = pd.read_csv(t_count_file_path)


# Applying the updated mapping with sequence numbers
for i, genome in enumerate(genomes_list, start=1):
    phylum = genome_to_phylum_map.get(genome)
    if phylum and genome in t_count_df.columns:
        new_column_name = f"{phylum}_{i}"  # Append underscore and sequence number
        print(new_column_name)
        t_count_df = t_count_df.rename(columns={genome: new_column_name})

# Display the first few rows of the modified DataFrame to verify changes
t_count_df.head()
# Out:
# p__Desulfobacterota_1
# p__Planctomycetota_2
# p__Proteobacteria_3
# p__Chloroflexota_4
# p__Bacteroidota_5
# p__Verrucomicrobiota_6
# p__Proteobacteria_7
# p__Actinobacteriota_8
# p__Krumholzibacteriota_9
# p__Armatimonadota_10
# p__Bacteroidota_11
# p__Verrucomicrobiota_12
# p__Actinobacteriota_13
# p__Firmicutes_A_14
# p__Desulfobacterota_15
#                                Unnamed: 0  Ga0485165_metabat1.097_sub  \
# 0    ME_2020_07_24_15m_B.fastq Read Count                         929
# 1  ME_2020_07_24_23_5M_B.fastq Read Count                       12747
# 2     ME_2020_07_24_5m_C.fastq Read Count                          24
# 3    ME_2020_08_05_10M_B.fastq Read Count                          40
# 4    ME_2020_08_05_15M_B.fastq Read Count                         416
#
#    Ga0485163_maxbin.015_sub  Ga0485161_metabat1.109_sub  \
# 0                       136                       21252
# 1                       264                        7253
# 2                       538                        7615
# 3                       589                        3019
# 4                       199                       15025
#
#    Ga0485163_metabat1.131  Ga0485165_metabat2_ours.031  \
# 0                   78567                       203159
# 1                   11930                        83501
# 2                     201                           50
# 3                  305572                         3168
# 4                   60601                       381617
#
#    Ga0485163_metabat1.023_sub  Ga0485171_metabat2_ours.194  \
# 0                        1456                          296
# 1                         585                           49
# 2                        8188                          139
# 3                        5636                          155
# 4                        1039                          127
#
#    Ga0485163_maxbin.004_sub  p__Verrucomicrobiota_6  ...  depth  \
# 0                       285                    1456  ...   15.0
# 1                        80                    4612  ...   23.5
# 2                       401                      16  ...    5.0
# 3                      1471                      49  ...   10.0
# 4                       289                    1084  ...   15.0
#
#    wtemp_in_celsius  DO_sat_perc  DO_mg_L  specific_conductivity    PH  \
# 0             12.03         -1.7    -0.18                 581.66  7.37
# 1             10.31         -1.5    -0.16                 600.14  7.17
# 2             25.05        109.1     9.00                 492.70  8.62
# 3             18.50         -0.7    -0.07                 570.32  7.47
# 4             11.76         -1.1    -0.12                 582.32  7.41
#
#    chlorophyll_RFU  phycocyanin_RFU  Dissolved_organic_matter_RFU  \
# 0             0.14             0.53                         12.18
# 1             0.35             0.88                         12.65
# 2             0.56             1.70                          9.70
# 3             0.33             0.87                         11.63
# 4             0.22             0.67                         12.18
#
#    Turbidity_RFU
# 0           0.59
# 1           1.71
# 2           4.99
# 3           0.86
# 4           0.72
#
# [5 rows x 442 columns]

# %%
t_count_df.to_csv('metatransciptome/tax_Betweenness.csv', index=True)

# %% [markdown]
# # Closeness

# %%
# List of genome names to map to Phylum
genomes_list = [
    "Ga0485157_metabat1.069",
"Ga0485157_metabat2_ours.025",
"Ga0485157_metabat2_ours.091",
"Ga0485158_metabat2_ours.184",
"Ga0485159_maxbin.015",
"Ga0485160_maxbin.155_sub",
"Ga0485160_metabat2_ours.051",
"Ga0485160_metabat2_ours.071",
"Ga0485161_metabat1.109_sub",
"Ga0485162_metabat2_ours.036",
"Ga0485163_maxbin.002_sub",
"Ga0485163_maxbin.104_sub",
"Ga0485163_maxbin.129",
"Ga0485163_maxbin.130_sub",
"Ga0485163_maxbin.183_sub",

]
# Load the taxonomy file again (repeating due to re-upload)
taxonomy_file_path = 'Fw_ lake mendota data/MAG_taxonomy.tsv'
taxonomy_df = pd.read_csv(taxonomy_file_path, sep='\t')

# Load the T-count file
t_count_file_path = 'metatransciptome_count.csv'
t_count_df = pd.read_csv(t_count_file_path)
genome_to_phylum_map = dict(zip(taxonomy_df['Genome'], taxonomy_df['Phylum']))
t_count_df = pd.read_csv(t_count_file_path)


# Applying the updated mapping with sequence numbers
for i, genome in enumerate(genomes_list, start=1):
    phylum = genome_to_phylum_map.get(genome)
    if phylum and genome in t_count_df.columns:
        new_column_name = f"{phylum}_{i}"  # Append underscore and sequence number
        print(new_column_name)
        t_count_df = t_count_df.rename(columns={genome: new_column_name})

# Display the first few rows of the modified DataFrame to verify changes
t_count_df.head()
# Out:
# p__Verrucomicrobiota_1
# p__Actinobacteriota_2
# p__Bacteroidota_3
# p__Bacteroidota_4
# p__Bacteroidota_5
# p__Actinobacteriota_6
# p__Bacteroidota_7
# p__Bacteroidota_8
# p__Actinobacteriota_9
# p__Proteobacteria_10
# p__Planctomycetota_11
# p__Proteobacteria_12
# p__Proteobacteria_13
# p__Bacteroidota_14
# p__Verrucomicrobiota_15
#                                Unnamed: 0  Ga0485165_metabat1.097_sub  \
# 0    ME_2020_07_24_15m_B.fastq Read Count                         929
# 1  ME_2020_07_24_23_5M_B.fastq Read Count                       12747
# 2     ME_2020_07_24_5m_C.fastq Read Count                          24
# 3    ME_2020_08_05_10M_B.fastq Read Count                          40
# 4    ME_2020_08_05_15M_B.fastq Read Count                         416
#
#    Ga0485163_maxbin.015_sub  p__Actinobacteriota_9  Ga0485163_metabat1.131  \
# 0                       136                  21252                   78567
# 1                       264                   7253                   11930
# 2                       538                   7615                     201
# 3                       589                   3019                  305572
# 4                       199                  15025                   60601
#
#    Ga0485165_metabat2_ours.031  Ga0485163_metabat1.023_sub  \
# 0                       203159                        1456
# 1                        83501                         585
# 2                           50                        8188
# 3                         3168                        5636
# 4                       381617                        1039
#
#    Ga0485171_metabat2_ours.194  Ga0485163_maxbin.004_sub  \
# 0                          296                       285
# 1                           49                        80
# 2                          139                       401
# 3                          155                      1471
# 4                          127                       289
#
#    Ga0485162_metabat2_ours.116  ...  depth  wtemp_in_celsius  DO_sat_perc  \
# 0                         1456  ...   15.0             12.03         -1.7
# 1                         4612  ...   23.5             10.31         -1.5
# 2                           16  ...    5.0             25.05        109.1
# 3                           49  ...   10.0             18.50         -0.7
# 4                         1084  ...   15.0             11.76         -1.1
#
#    DO_mg_L  specific_conductivity    PH  chlorophyll_RFU  phycocyanin_RFU  \
# 0    -0.18                 581.66  7.37             0.14             0.53
# 1    -0.16                 600.14  7.17             0.35             0.88
# 2     9.00                 492.70  8.62             0.56             1.70
# 3    -0.07                 570.32  7.47             0.33             0.87
# 4    -0.12                 582.32  7.41             0.22             0.67
#
#    Dissolved_organic_matter_RFU  Turbidity_RFU
# 0                         12.18           0.59
# 1                         12.65           1.71
# 2                          9.70           4.99
# 3                         11.63           0.86
# 4                         12.18           0.72
#
# [5 rows x 442 columns]

# %%
t_count_df.to_csv('metatransciptome/tax_Closeness.csv', index=True)

# %% [markdown]
# # Page Rank

# %%
# List of genome names to map to Phylum
genomes_list = [
    "Ga0485158_metabat2_ours.098",
"Ga0485166_metabat2_ours.038",
"Ga0485167_metabat2_ours.023",
"Ga0485170_maxbin.090",
"Ga0485161_metabat2_ours.167_sub",
"Ga0485171_maxbin.130_sub",
"Ga0485161_maxbin.110",
"Ga0485164_metabat2_ours.069_sub",
"Ga0485171_metabat1.063",
"Ga0485159_metabat2_ours.079",
"Ga0485171_metabat2_ours.127_sub",
"Ga0485159_metabat2_ours.155_sub",
"Ga0485158_metabat1.076",
"Ga0485171_metabat1.030",
"Ga0485168_metabat2_ours.135_sub"
]
# Load the taxonomy file again (repeating due to re-upload)
taxonomy_file_path = 'Fw_ lake mendota data/MAG_taxonomy.tsv'
taxonomy_df = pd.read_csv(taxonomy_file_path, sep='\t')

# Load the T-count file
t_count_file_path = 'metatransciptome_count.csv'
t_count_df = pd.read_csv(t_count_file_path)
genome_to_phylum_map = dict(zip(taxonomy_df['Genome'], taxonomy_df['Phylum']))
t_count_df = pd.read_csv(t_count_file_path)


# Applying the updated mapping with sequence numbers
for i, genome in enumerate(genomes_list, start=1):
    phylum = genome_to_phylum_map.get(genome)
    if phylum and genome in t_count_df.columns:
        new_column_name = f"{phylum}_{i}"  # Append underscore and sequence number
        print(new_column_name)
        t_count_df = t_count_df.rename(columns={genome: new_column_name})

# Display the first few rows of the modified DataFrame to verify changes
t_count_df.head()
# Out:
# p__Krumholzibacteriota_1
# p__Bacteroidota_2
# p__Verrucomicrobiota_3
# p__Planctomycetota_4
# p__Verrucomicrobiota_5
# p__Planctomycetota_6
# p__Proteobacteria_7
# p__Proteobacteria_8
# p__Bacteroidota_9
# p__Bacteroidota_10
# p__Bacteroidota_11
# p__Actinobacteriota_12
# p__Verrucomicrobiota_13
# p__Proteobacteria_14
# p__Planctomycetota_15
#                                Unnamed: 0  Ga0485165_metabat1.097_sub  \
# 0    ME_2020_07_24_15m_B.fastq Read Count                         929
# 1  ME_2020_07_24_23_5M_B.fastq Read Count                       12747
# 2     ME_2020_07_24_5m_C.fastq Read Count                          24
# 3    ME_2020_08_05_10M_B.fastq Read Count                          40
# 4    ME_2020_08_05_15M_B.fastq Read Count                         416
#
#    Ga0485163_maxbin.015_sub  Ga0485161_metabat1.109_sub  \
# 0                       136                       21252
# 1                       264                        7253
# 2                       538                        7615
# 3                       589                        3019
# 4                       199                       15025
#
#    Ga0485163_metabat1.131  Ga0485165_metabat2_ours.031  \
# 0                   78567                       203159
# 1                   11930                        83501
# 2                     201                           50
# 3                  305572                         3168
# 4                   60601                       381617
#
#    Ga0485163_metabat1.023_sub  Ga0485171_metabat2_ours.194  \
# 0                        1456                          296
# 1                         585                           49
# 2                        8188                          139
# 3                        5636                          155
# 4                        1039                          127
#
#    Ga0485163_maxbin.004_sub  Ga0485162_metabat2_ours.116  ...  depth  \
# 0                       285                         1456  ...   15.0
# 1                        80                         4612  ...   23.5
# 2                       401                           16  ...    5.0
# 3                      1471                           49  ...   10.0
# 4                       289                         1084  ...   15.0
#
#    wtemp_in_celsius  DO_sat_perc  DO_mg_L  specific_conductivity    PH  \
# 0             12.03         -1.7    -0.18                 581.66  7.37
# 1             10.31         -1.5    -0.16                 600.14  7.17
# 2             25.05        109.1     9.00                 492.70  8.62
# 3             18.50         -0.7    -0.07                 570.32  7.47
# 4             11.76         -1.1    -0.12                 582.32  7.41
#
#    chlorophyll_RFU  phycocyanin_RFU  Dissolved_organic_matter_RFU  \
# 0             0.14             0.53                         12.18
# 1             0.35             0.88                         12.65
# 2             0.56             1.70                          9.70
# 3             0.33             0.87                         11.63
# 4             0.22             0.67                         12.18
#
#    Turbidity_RFU
# 0           0.59
# 1           1.71
# 2           4.99
# 3           0.86
# 4           0.72
#
# [5 rows x 442 columns]

# %%
t_count_df.to_csv('metatransciptome/tax_Page_Rank.csv', index=True)

# %% [markdown]
# # Degree

# %%
# List of genome names to map to Phylum
genomes_list = [
    "Ga0485158_metabat2_ours.098",
"Ga0485159_metabat2_ours.079",
"Ga0485171_metabat2_ours.127_sub",
"Ga0485171_metabat2_ours.004",
"Ga0485170_maxbin.090",
"Ga0485171_metabat1.063",
"Ga0485157_metabat2_ours.019",
"Ga0485166_metabat2_ours.038",
"Ga0485167_metabat2_ours.023",
"Ga0485170_maxbin.059_sub",
"Ga0485171_maxbin.130_sub",
"Ga0485160_metabat2_ours.158_sub",
"Ga0485161_maxbin.110",
"Ga0485161_metabat1.096",
"Ga0485161_metabat2_ours.167_sub"

]
# Load the taxonomy file again (repeating due to re-upload)
taxonomy_file_path = 'Fw_ lake mendota data/MAG_taxonomy.tsv'
taxonomy_df = pd.read_csv(taxonomy_file_path, sep='\t')

# Load the T-count file
t_count_file_path = 'metatransciptome_count.csv'
t_count_df = pd.read_csv(t_count_file_path)
genome_to_phylum_map = dict(zip(taxonomy_df['Genome'], taxonomy_df['Phylum']))
t_count_df = pd.read_csv(t_count_file_path)


# Applying the updated mapping with sequence numbers
for i, genome in enumerate(genomes_list, start=1):
    phylum = genome_to_phylum_map.get(genome)
    if phylum and genome in t_count_df.columns:
        new_column_name = f"{phylum}_{i}"  # Append underscore and sequence number
        print(new_column_name)
        t_count_df = t_count_df.rename(columns={genome: new_column_name})

# Display the first few rows of the modified DataFrame to verify changes
t_count_df.head()
# Out:
# p__Krumholzibacteriota_1
# p__Bacteroidota_2
# p__Bacteroidota_3
# p__Proteobacteria_4
# p__Planctomycetota_5
# p__Bacteroidota_6
# p__Chloroflexota_7
# p__Bacteroidota_8
# p__Verrucomicrobiota_9
# p__Actinobacteriota_10
# p__Planctomycetota_11
# p__Chloroflexota_12
# p__Proteobacteria_13
# p__Firmicutes_A_14
# p__Verrucomicrobiota_15
#                                Unnamed: 0  Ga0485165_metabat1.097_sub  \
# 0    ME_2020_07_24_15m_B.fastq Read Count                         929
# 1  ME_2020_07_24_23_5M_B.fastq Read Count                       12747
# 2     ME_2020_07_24_5m_C.fastq Read Count                          24
# 3    ME_2020_08_05_10M_B.fastq Read Count                          40
# 4    ME_2020_08_05_15M_B.fastq Read Count                         416
#
#    Ga0485163_maxbin.015_sub  Ga0485161_metabat1.109_sub  \
# 0                       136                       21252
# 1                       264                        7253
# 2                       538                        7615
# 3                       589                        3019
# 4                       199                       15025
#
#    Ga0485163_metabat1.131  Ga0485165_metabat2_ours.031  \
# 0                   78567                       203159
# 1                   11930                        83501
# 2                     201                           50
# 3                  305572                         3168
# 4                   60601                       381617
#
#    Ga0485163_metabat1.023_sub  Ga0485171_metabat2_ours.194  \
# 0                        1456                          296
# 1                         585                           49
# 2                        8188                          139
# 3                        5636                          155
# 4                        1039                          127
#
#    Ga0485163_maxbin.004_sub  Ga0485162_metabat2_ours.116  ...  depth  \
# 0                       285                         1456  ...   15.0
# 1                        80                         4612  ...   23.5
# 2                       401                           16  ...    5.0
# 3                      1471                           49  ...   10.0
# 4                       289                         1084  ...   15.0
#
#    wtemp_in_celsius  DO_sat_perc  DO_mg_L  specific_conductivity    PH  \
# 0             12.03         -1.7    -0.18                 581.66  7.37
# 1             10.31         -1.5    -0.16                 600.14  7.17
# 2             25.05        109.1     9.00                 492.70  8.62
# 3             18.50         -0.7    -0.07                 570.32  7.47
# 4             11.76         -1.1    -0.12                 582.32  7.41
#
#    chlorophyll_RFU  phycocyanin_RFU  Dissolved_organic_matter_RFU  \
# 0             0.14             0.53                         12.18
# 1             0.35             0.88                         12.65
# 2             0.56             1.70                          9.70
# 3             0.33             0.87                         11.63
# 4             0.22             0.67                         12.18
#
#    Turbidity_RFU
# 0           0.59
# 1           1.71
# 2           4.99
# 3           0.86
# 4           0.72
#
# [5 rows x 442 columns]

# %%
t_count_df.to_csv('metatransciptome/tax_Degree.csv', index=True)
